# %% [markdown]
# ## Notebook 0: Sample information
#
# In this notebook we will load the master data spreadsheet with sample information, including barcodes, and extract new barcode files matching barcode sequences to the cleaned up sample names that we want appended to each demultiplexed fastq file.

# %%
import pandas as pd

# %% [markdown]
# ### Load full sample info table

# %%
df = pd.read_csv("../data_sample_info/mastersheetSamples_RADstrep_20191017.csv")
df.info(True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 15 columns):
# n                           106 non-null int64
# sampleID_NickJ              106 non-null object
# barcode                     106 non-null object
# run                         106 non-null object
# tip_label_ivalu             106 non-null object
# species                     106 non-null object
# 4balanced                   106 non-null int64
# 4BPP                        106 non-null int64
# sample_uid                  106 non-null object
# HebrariumAccession_NickJ    106 non-null object
# locality                    69 non-null object
# whoseSample                 106 non-null object
# collection_N                106 non-null object
# sample_name_NickJ           106 non-null object
# notes                       1 non-null object
# dtypes: int64(3), object(12)
# memory usage: 12.5+ KB

# %% [markdown]
# ### Extract barcodes map file for library 1

# %%
# select the first library only
subdf = df[df.run == "run_1"].reset_index()

# strip the cutsite (TGCAG) from the end of barcode sequence
subdf.loc[:, "barcode"] = subdf.barcode.str.rsplit("TGCAG", 1, expand=True)[0]

# %%
# there are 66 samples all with 10bp barcodes
subdf.barcode.apply(len).describe()
# Out:
# count    66.0
# mean     10.0
# std       0.0
# min      10.0
# 25%      10.0
# 50%      10.0
# 75%      10.0
# max      10.0
# Name: barcode, dtype: float64

# %%
# select the two columns for the barcodes file
final = subdf.loc[:, ["tip_label_ivalu", "barcode"]]

# write this data to a file
final.to_csv(
    "../data_rad_and_barcodes/barcodes_UO_C601_1.csv", 
    sep="\t",
    header=False, 
    index=False,
)

# show the whole thing here for prosperity
with pd.option_context('display.max_rows', 150):
    display(final)
# Out:
#                   tip_label_ivalu     barcode
# 0             C_amp_barbarae_e020  TTGATGGTGC
# 1                 C_anceps_nic053  CTTCGACATA
# 2               C_flavescens_e003  TCATAGGCTA
# 3               S_hesperidis_e043  ATCCGTCTAC
# 4               S_howellii_nic152  TAGTGCGGTC
# 5                S_tortuosus_e040  GCCGGTGATT
# 6                The_crispum_e084  TCACTGAGAA
# 7        C_amp_amplexicaulis_e068  CAACATGAAG
# 8                 C_coulteri_e015  GCGTCCTGCC
# 9                   C_hallii_e078  ATGAAGGCAG
# 10         C_heterophyllus_nic027  GCAATATACA
# 11                C_inflatus_e044  ACTTGACCGG
# 12  C_lasyophyllus_CalBod032213_1  GAATTGTCGC
# 13              S_barbatus_nic176  GAGATATGGT
# 14                S_barbiger_e045  CGCTATACGG
# 15              S_barbiger_nic193  AAGAATTCGG
# 16             S_bernardinus_e095  GCTGCACGGT
# 17              S_brachiatus_e100  CACGCAACGA
# 18              S_bracteatus_e120  GCATGGAGGT
# 19                 S_breweri_e035  TGTCCTAGGA
# 20           S_campestris_NJ_3785  AGCTTCGATT
# 21           S_campestris_NJ_3800  TTGCGCAAGC
# 22                S_cordatus_e054  GCCGCAATGC
# 23              S_cordatus_nic139  ACTGCCTCAA
# 24           S_diversifolius_e077  ATCCATAAGA
# 25         S_farnsworthianus_e034  CTGTTAGATT
# 26           S_longisiliquus_e055  CTCATTAACC
# 27         S_longisiliquus_nic180  TCGGCAGTCG
# 28            S_medeirosii_NJ_525  TACGATGGAG
# 29              S_morrisonii_e016  GGACTCACGG
# 30           S_oliganthus_NJ_3801  GTTGCTAGAC
# 31                 S_pilosus_e053  CATGCATACT
# 32            S_polygaloides_e071  TAACTGGTAC
# 33        S_spnov_aarthur_NJ_0038  TTCTTGCGCT
# 34              Si_hammittii_e111  GATGGACTAA
# 35           Sl_longirostris_e065  TATCGCGGAG
# 36                  St_elata_e093  GTATATCCAC
# 37                St_pinnata_e090  CGTACCTTGC
# 38                Sy_irio_NJ_3877  AGGAACCTCG
# 39        S_barbatus_Janeway_7367  CGGCTACTTC
# 40          S_bernardinus_NJ_3777  TTATCCGTAG
# 41          S_bernardinus_NJ_3797  AATAGATTCA
# 42       S_bernardinus_White_8769  GTGTCTCTTG
# 43           S_campestris_NJ_3784  CTAACACGGC
# 44           S_campestris_NJ_3793  CAAGCCGGTT
# 45         S_cordatus_Andre_12643  TTCTGGAATA
# 46           S_cordatus_Bell_8389  TGCAGTTATC
# 47                S_cordatus_e086  CGCTTCTCTG
# 48       S_cordatus_Hodgson_23698  GGCCGGTAAC
# 49          S_cordatus_Moore_3278  TCGTCTTAGT
# 50              S_cordatus_nic262  TATCGTTAGT
# 51             S_cordatus_NJ_1569  AGCTGATACA
# 52             S_cordatus_NJ_3637  TCCGGAGCGC
# 53             S_cordatus_NJ_3686  ATCAGTAGAA
# 54             S_cordatus_NJ_3818  TCAGTTCCGG
# 55             S_cordatus_NJ_3825  TCGCCGCAAT
# 56        S_cordatus_Scord_Oregon  AGCAATCTAA
# 57             S_glandulosus_d125  GCTCAGCCAG
# 58             S_glandulosus_e041  AATGGTGACT
# 59             S_glandulosus_e081  CTAACAGTAT
# 60           S_longisiliquus_D116  AGTTCCATTG
# 61          S_medeirosii_NJ_2419a  ACATCAATAT
# 62        S_medeirosii_UCR_251770  ACGCAACACA
# 63           S_oliganthus_NJ_3805  CGGAAGTGAG
# 64        S_oliganthus_RENO_18159  CCTCTTATCA
# 65     S_tortuosus_Helmkamp_17516  CTCCTTGGAG

# %% [markdown]
# ### Extract barcodes map file for library 2

# %%
# select the first library only
subdf = df[df.run == "run_2"].reset_index()

# cutsite (TGCAG) has already been stripped from the sequences
#subdf.loc[:, "barcode"] = subdf.barcode.str.rsplit("TGCAG", 1, expand=True)[0]

# %%
# there are 40 samples all with 7-10bp barcodes
subdf.barcode.apply(len).describe()
# Out:
# count    40.000000
# mean      8.725000
# std       1.109111
# min       7.000000
# 25%       8.000000
# 50%       9.000000
# 75%      10.000000
# max      10.000000
# Name: barcode, dtype: float64

# %%
# select the two columns for the barcodes file
final = subdf.loc[:, ["tip_label_ivalu", "barcode"]]

# write this data to a file
final.to_csv("../data_rad_and_barcodes/barcodes_Undet_lib2.csv")

# show the whole thing here for prosperity
with pd.option_context('display.max_rows', 150):
    display(final)
# Out:
#                  tip_label_ivalu     barcode
# 0           S_glandulosus_nic202   GCCGTAGGT
# 1         C_californicus_NJ_3881   ACCATATAT
# 2         C_glaucus_Porter_15587   AGACGGTTC
# 3                C_major_NJ_4561   TCCGTCGAA
# 4             S_barbatus_NJ_4393     CTCGATT
# 5          S_bernardinus_NJ_4775     TCAGAAC
# 6    S_glandulosus_albidus_d108A  AGACGTTAGG
# 7               S_juneae_NJ_4772   ACCAGGCCG
# 8        Thly_aurea_Porter_15531   AACCATGGA
# 9             S_barbatus_NJ_4388   GCGTCCAGG
# 10            S_barbatus_NJ_4394  GCCTGGAAGT
# 11            S_barbatus_NJ_4395  CTCGCGCAGT
# 12         S_bernardinus_NJ_3777  GCAGGTCAGT
# 13         S_bernardinus_NJ_4583     AAGTAAG
# 14         S_bernardinus_NJ_4770    TGCGACGT
# 15     S_campestris_Burgess_1353   CTCGCCGAT
# 16     S_campestris_Burgess_1353   TGAACCTTC
# 17          S_campestris_NJ_3791    AATTGCAT
# 18          S_campestris_NJ_3793     CTATGAT
# 19          S_campestris_NJ_3800    AACTCGGT
# 20          S_campestris_NJ_4626   TTGGACGAG
# 21          S_campestris_NJ_4627  CTCATAGATT
# 22      S_campestris_Rebman_9956    TTAGGTAC
# 23            S_cordatus_NJ_4387     TGATTCT
# 24     S_cordatus_Stoughton_2201  CCGCCTATGG
# 25            S_howellii_NJ_4382  CTTACCATCT
# 26            S_howellii_NJ_4383  GGATTGCAGT
# 27            S_howellii_NJ_4385     GCATTGC
# 28            S_howellii_NJ_4386  CAACCTTAAG
# 29              S_juneae_NJ_4773  CTCCGTTATG
# 30              S_juneae_NJ_4774  GGCCGGTATT
# 31       S_longisiliquus_NJ_4379    AAGAGATT
# 32       S_longisiliquus_NJ_4398    TCGAGCTG
# 33       S_longisiliquus_NJ_4399    AACTAACG
# 34         S_medeirosii_NJ_2419b     TCGCCTG
# 35         S_medeirosii_NJ_4764a    CTTCTATG
# 36         S_medeirosii_NJ_4764b    TTCAGGTT
# 37           S_polygaloides_D088  GATCGTAGTT
# 38           S_tortuosus_NJ_3665    CGCAGGAG
# 39  Sl_longirostris_Porter_15532  CATGGCAACT
